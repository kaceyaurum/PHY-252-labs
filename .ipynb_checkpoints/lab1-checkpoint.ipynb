# %%
room = 297.15

distance = .5

# DCR = 20 points/s

diameter = .0495

length = .875

height = .875 + .0495/2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import peakutils
from __future__ import division
import scipy
# %matplotlib inline

# %%
vals = pd.DataFrame({'room temperature (K)':room, 'length of string (m)':length, 'diameter of ball (m)':diameter, 'distance between pivot point and center of mass (m)':height}, index=[''])

# %%
vals
# Out:
#   diameter of ball (m)  distance between pivot point and center of mass (m)  \
#                 0.0495                                            0.89975
#
#   length of string (m)  room temperature (K)
#                  0.875                297.15

# %%
data = pd.read_csv('/home/kreidy/PHY-252-labs/lab1-data.csv')

# %%
data
# Out:
#       Unnamed: 0    time         x         v         a
# 0              0    0.05  0.823606 -0.488357 -1.354608
# 1              1    0.10  0.800983 -0.545540 -1.631983
# 2              2    0.15  0.773178 -0.635018 -1.964846
# 3              3    0.20  0.738983 -0.752876 -2.068967
# 4              4    0.25  0.697190 -0.861389 -1.766721
# 5              5    0.30  0.652115 -0.948027 -1.089897
# 6              6    0.35  0.598924 -0.967696 -0.427432
# 7              7    0.40  0.555058 -0.971246 -0.097224
# 8              8    0.45  0.502902 -0.984966  0.328290
# 9              9    0.50  0.453510 -0.942558  0.823523
# 10            10    0.55  0.408954 -0.897368  1.269292
# 11            11    0.60  0.363015 -0.826274  1.896982
# 12            12    0.65  0.323985 -0.708646  2.521900
# 13            13    0.70  0.291000 -0.562043  2.917297
# 14            14    0.75  0.267858 -0.410450  3.138503
# 15            15    0.80  0.249379 -0.241972  3.101084
# 16            16    0.85  0.243334 -0.082896  2.635860
# 17            17    0.90  0.240744  0.065146  1.506221
# 18            18    0.95  0.259914  0.043751  0.922346
# 19            19    1.00  0.243334  0.055840  2.146704
# 20            20    1.05  0.254042  0.267493  3.286843
# 21            21    1.10  0.272693  0.450843  3.260459
# 22            22    1.15  0.300843  0.610399  2.744438
# 23            23    1.20  0.335211  0.726491  2.082901
# 24            24    1.25  0.374586  0.814472  1.499878
# 25            25    1.30  0.417761  0.874054  0.972610
# 26            26    1.35  0.462836  0.910417  0.487664
# 27            27    1.40  0.509810  0.922506  0.013859
# 28            28    1.45  0.556094  0.909553 -0.430684
# 29            29    1.50  0.600996  0.882977 -0.931727
# ...          ...     ...       ...       ...       ...
# 1970        1970   98.55  0.508256  0.013816  0.033048
# 1971        1971   98.60  0.508947  0.015351  0.024786
# 1972        1972   98.65  0.509810  0.016502  0.014285
# 1973        1973   98.70  0.510674  0.016311  0.011886
# 1974        1974   98.75  0.511365  0.017366  0.014019
# 1975        1975   98.80  0.512401  0.018421  0.002505
# 1976        1976   98.85  0.513264  0.018229 -0.020468
# 1977        1977   98.90  0.514301  0.016407 -0.043442
# 1978        1978   98.95  0.514991  0.012953 -0.049198
# 1979        1979   99.00  0.515510  0.010842 -0.043122
# 1980        1980   99.05  0.516028  0.009403 -0.048772
# 1981        1981   99.10  0.516546  0.006428 -0.062204
# 1982        1982   99.15  0.516718  0.002495 -0.064603
# 1983        1983   99.20  0.516718 -0.000288 -0.061138
# 1984        1984   99.25  0.516718 -0.003454 -0.058473
# 1985        1985   99.30  0.516373 -0.006428 -0.050691
# 1986        1986   99.35  0.516028 -0.008539 -0.043388
# 1987        1987   99.40  0.515510 -0.010458 -0.041416
# 1988        1988   99.45  0.514991 -0.012473 -0.042589
# 1989        1989   99.50  0.514301 -0.015063 -0.037152
# 1990        1990   99.55  0.513437 -0.016694 -0.022334
# 1991        1991   99.60  0.512574 -0.017174 -0.009168
# 1992        1992   99.65  0.511710 -0.017270 -0.002079
# 1993        1993   99.70  0.510847 -0.017270  0.002985
# 1994        1994   99.75  0.509983 -0.017174  0.013091
# 1995        1995   99.80  0.509120 -0.016502  0.033143
# 1996        1996   99.85  0.508256 -0.014200  0.056788
# 1997        1997   99.90  0.507565 -0.009729  0.059709
# 1998        1998   99.95  0.507393 -0.007004  0.041395
# 1999        1999  100.00  0.507047 -0.006524  0.024007
#
# [2000 rows x 5 columns]

# %% [markdown]
# data['time'] = data['Latest: Time (s)']
# data['x'] = data['Latest: Position (m)']
# data['v'] = data['Latest: Velocity (m/s)']
# data['a'] = data['Latest: Acceleration (m/s²)']

# %%
ax = plt.subplot()
fig = plt.subplot(111)
ax.set_xlabel('time (s)')
ax.set_ylabel('position (m)')
ax.set_title('discrete position vs time of pendulum motion')
ax.scatter(data['time'], data['x'], label='collected position data')
ax.axhline(np.average(data['x']), color=(1,0,0), label='average position')
ax.legend()
ax.figure.savefig('lab1_x-t_scatterplot')
# Out:
# /home/kreidy/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
ax = plt.subplot()
fig = plt.subplot(111)
ax.set_xlabel('time (s)')
ax.set_ylabel('position (m)')
ax.set_title('linearly connected points of position vs time of pendulum motion')
ax.plot(data['time'], data['x'], label='collected position data')
ax.axhline(np.average(data['x']), color=(1,0,0), label='average position')
ax.legend()
ax.figure.savefig('lab1_x-t_lineplot')
# Out:
# /home/kreidy/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
def guessfit(t,A,y,w,theta,phi):
    return A*np.e**(-y*t)*np.cos(w*t+theta)+phi

# %%
params, paramcovs = scipy.optimize.curve_fit(guessfit, data['time'], data['x'])

# %%
params

# %%
paramcovs

# %%
deltas = np.sqrt(np.diag(paramcovs))

# %%
parameters = pd.DataFrame({'optimal value':params, 'delta':deltas}, index=['A', 'y', 'w', 'theta', 'phi'])

# %%
parameters
# Out:
#           delta  optimal value
# A      0.000747       0.283427
# y      0.000181       0.048578
# w      0.000180       3.283436
# theta  0.002617       0.052817
# phi    0.000119       0.511907

# %%
intery = []
for t in data['time']:
    intery.append(parameters['optimal value']['A']*np.e**(-parameters['optimal value']['y']*t)
                  *np.cos(parameters['optimal value']['w']*t+parameters['optimal value']['theta'])
                  +parameters['optimal value']['phi'])

# %%
scipy.rmsd?

# %%
intery
# Out:
# [0.78801640988805444,
#  0.77371871081471155,
#  0.75246521886733586,
#  0.72485992696085855,
#  0.69167433597562455,
#  0.6538259416867308,
#  0.61235290853211954,
#  0.56838562826509831,
#  0.52311594174068388,
#  0.47776486101782206,
#  0.4335496651428829,
#  0.39165125555322133,
#  0.35318264578006686,
#  0.31915942545518305,
#  0.29047298157948886,
#  0.26786718223328426,
#  0.25191913158432272,
#  0.24302449285620109,
#  0.24138775094273812,
#  0.24701765200958792,
#  0.25972791736246531,
#  0.27914318686798734,
#  0.30471000710764706,
#  0.33571254497807568,
#  0.52141559197630749,
#  0.52560620750184728,
#  0.52940892400988326,
#  0.53272358472308812,
#  0.53546361399976961,
#  0.53755827456389682,
#  0.53895448881303099,
#  0.53961817744633311,
#  0.53953508183292254,
#  0.53871105055615043,
#  0.53717178504168639,
#  0.53496205371613781,
#  0.53214439835782479,
#  0.52879736981244163,
#  0.52501334269452671,
#  0.5208959697520843,
#  0.51655734594641134,
#  0.51211495974877996,
#  0.50768851448958374,
#  0.50339670568092976,
#  0.49935404099865138,
#  0.49566778804497458,
#  0.49243513117187454,
#  0.48974061264166835,
#  0.48765392540710506,
#  0.48622811503230795,
#  0.48549823701890427,
#  0.48548050335779458,
#  0.48617193883595577,
#  0.48755055385016599,
#  0.48957602658762644,
#  0.4921908738004509,
#  0.49532207639144715,
#  0.49888311398857532,
#  0.50277635193333425,
#  0.50689571492631891,
#  0.51112957420010208,
#  0.51536376971452424,
#  0.51948468562689498,
#  0.52338229625625299,
#  0.52695310095374626,
#  0.5301028696674368,
#  0.5327491264484594,
#  0.5348233055296846,
#  0.53627252371053502,
#  0.53706092334975974,
#  0.5371705520110911,
#  0.5366017574040377,
#  0.53537308937143413,
#  0.5335207139425181,
#  0.53109735753850995,
#  0.52817081193722581,
#  ...]

# %%
intery = pd.DataFrame(intery, columns=['intery'])

# %%
intery.set_index(data['time'])
# Out:
#           intery
# time
# 0.05    0.788016
# 0.10    0.773719
# 0.15    0.752465
# 0.20    0.724860
# 0.25    0.691674
# 0.30    0.653826
# 0.35    0.612353
# 0.40    0.568386
# 0.45    0.523116
# 0.50    0.477765
# 0.55    0.433550
# 0.60    0.391651
# 0.65    0.353183
# 0.70    0.319159
# 0.75    0.290473
# 0.80    0.267867
# 0.85    0.251919
# 0.90    0.243024
# 0.95    0.241388
# 1.00    0.247018
# 1.05    0.259728
# 1.10    0.279143
# 1.15    0.304710
# 1.20    0.335713
# 1.25    0.371293
# 1.30    0.410473
# 1.35    0.452186
# 1.40    0.495299
# 1.45    0.538648
# 1.50    0.581070
# ...          ...
# 98.55   0.509548
# 98.60   0.509605
# 98.65   0.509723
# 98.70   0.509900
# 98.75   0.510130
# 98.80   0.510406
# 98.85   0.510721
# 98.90   0.511066
# 98.95   0.511433
# 99.00   0.511810
# 99.05   0.512188
# 99.10   0.512557
# 99.15   0.512906
# 99.20   0.513227
# 99.25   0.513511
# 99.30   0.513750
# 99.35   0.513939
# 99.40   0.514073
# 99.45   0.514147
# 99.50   0.514162
# 99.55   0.514115
# 99.60   0.514010
# 99.65   0.513848
# 99.70   0.513636
# 99.75   0.513378
# 99.80   0.513081
# 99.85   0.512755
# 99.90   0.512408
# 99.95   0.512048
# 100.00  0.511687
#
# [2000 rows x 1 columns]

# %%
data.set_index(data['time'])
# Out:
#         Unnamed: 0    time         x         v         a
# time
# 0.05             0    0.05  0.823606 -0.488357 -1.354608
# 0.10             1    0.10  0.800983 -0.545540 -1.631983
# 0.15             2    0.15  0.773178 -0.635018 -1.964846
# 0.20             3    0.20  0.738983 -0.752876 -2.068967
# 0.25             4    0.25  0.697190 -0.861389 -1.766721
# 0.30             5    0.30  0.652115 -0.948027 -1.089897
ax = plt.subplot()
fig = plt.subplot(111)
ax.set_xlabel('time (s)')
ax.set_ylabel('position (m)')
ax.set_title('observed pendulum motion with calculated extrema shown')
ax.plot(data['time'], data['x'], label='collected position data')
ax.plot(data['time'], intery, color='#FF00BD', label='interpolated position data')
ax.axhline(np.average(data['x']), color=(1,0,0), label='average position')
ax.legend()
ax.figure.savefig('lab1_x-t_intplot')
# Out:
# /home/kreidy/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
np.average(intery) - np.average(data['x'])
# Out:
# 6.0063065632220969e-14

# %%
residuals = intery - data['x']
ax = plt.subplot()
fig = plt.subplot(111)
ax.set_xlabel('time (s)')
ax.set_ylabel('position (m)')
ax.set_title('observed pendulum motion with calculated extrema shown')
ax.plot(data['time'], residuals, label='interpolated position data and collected position data difference')
ax.legend()
ax.axhline(np.average(data['x']), color=(1,0,0), label='average position')

ax.figure.savefig('lab1_x-t_intplot')
# Out:
# /home/kreidy/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
maxes = pu.indexes(data['x'], thres=.5)
mins = pu.indexes(-data['x'], thres=.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-8cb36d875718> in <module>()
# ----> 1 maxes = pu.indexes(data['x'], thres=.5)
#       2 mins = pu.indexes(-data['x'], thres=.5)
#
# NameError: name 'pu' is not defined

# %%
ax = plt.subplot()
fig = plt.subplot(111)
ax.set_xlabel('time (s)')
ax.set_ylabel('position (m)')
ax.set_title('observed pendulum motion with calculated extrema shown')
ax.plot(data['time'], data['x'], label='collected position data')
ax.scatter(data['time'][maxes], data['x'][maxes], color=(1,.5,0), label='relative maxima')
ax.scatter(data['time'][mins], data['x'][mins], color=(0,1,0), label='relative minima')
ax.legend()
ax.axhline(np.average(data['x']), color=(1,0,0))
ax.figure.savefig('lab1_x-t_pupeakslineplot')

# %% [markdown]
# A

# %% [markdown]
# def getrmsd(pos, data=data):
#     return np.sqrt(((pos-data['x'])**2).mean())

# %% [markdown]
# def getgamma():
#     y = 0
#     t = data['time']
#     phi = midp
#     dy = .01
#     goody = y
#     while dy >= .001:
#         currentpos = A*np.e**(-goody*t)*np.cos(w*t+theta)+phi
#         rmsd = getrmsd(currentpos)
#         for i in range(0,10):
#             dummyy = y + i*dy
#             newpos = A*np.e**(-dummyy*t)*np.cos(w*t+theta)+phi
#             temprmsd = getrmsd(newpos)
# #             print(dummyy, temprmsd)
#             if temprmsd < rmsd:
#                 rmsd = temprmsd
#                 goody = dummyy
#         y = goody
#         dy /= 10
#     return y

# %% [markdown]
# y = getgamma()

# %% [markdown]
# def getomega():
#     w = 0
#     t = data['time']
#     phi = midp
#     dw = 1
#     goodw = w
#     while dw >= .01:
#         currentpos = A*np.e**(-y*t)*np.cos(goodw*t+theta)+phi
#         rmsd = getrmsd(currentpos)
#         for i in range(0,10):
#             dummyw = w + i*dw
#             newpos = A*np.e**(-y*t)*np.cos(dummyw*t+theta)+phi
#             temprmsd = getrmsd(newpos)
#             if temprmsd < rmsd:
#                 rmsd = temprmsd
#                 goodw = dummyw
#         w = goodw
#         dw /= 10
#     return w

# %% [markdown]
# w = getomega()

# %% [markdown]
# def gettheta():
#     t = data['time']
#     th = 0
#     phi = midp
#     dth = np.pi/24
#     goodth = th
#     while dth >= .01:
#         currentpos = A*np.e**(-y*t)*np.cos(w*t+goodth)+phi
#         rmsd = getrmsd(currentpos)
#         for i in range(0,12):
#             dummyth = th + i*dth
#             newpos = A*np.e**(-y*t)*np.cos(w*t+dummyth)+phi
#             temprmsd = getrmsd(newpos)
#             if temprmsd < rmsd:
#                 rmsd = temprmsd
#                 goodth = dummyth
#         th = goodth
#         dth /= 10
#     return th

# %% [markdown]
# gettheta()

# %% [markdown]
# np.pi/12

# %% [markdown]
# print(y, w, theta)

# %% [markdown]
# def realA():
#     A = max(max(abs(data['x'][maxes]-midp)), max(abs(data['x'][mins]-midp)))
#     t = data['time']
#     phi = midp
#     dA = 1
#     goodA = A
#     while dA >= .001:
#         currentpos = goodA*np.e**(-y*t)*np.cos(w*t+theta)+phi
#         rmsd = getrmsd(currentpos)
#         for i in range(0,10):
#             dummyA = A + i*dA
#             newpos = dummyA*np.e**(-y*t)*np.cos(w*t+theta)+phi
#             temprmsd = getrmsd(newpos)
#             if temprmsd < rmsd:
#                 rmsd = temprmsd
#                 goodA = dummyA
#         A = goodA
#         dA /= 10
#     return A

# %% [markdown]
# def getvars(cutoff, A=A, y=y, w=w, theta=theta):
#     t = data['time']
#     phi = midp
#     A = max(max(abs(data['x'][maxes]-midp)), max(abs(data['x'][mins]-midp)))
#     y = 0
# #     w = 0
#     pos = A*np.e**(-y*t)*np.cos(w*t+theta)+phi
#     rmsd = getrmsd(pos)
#     while rmsd > cutoff:
#         theta = gettheta()
#         w = getomega()
#         y = getgamma()
#         A = realA()
#         pos = A*np.e**(-y*t)*np.cos(w*t+theta)+phi
#         tempval = getrmsd(pos)
#         if tempval < rmsd:
#             rmsd = tempval
#     return A, y, w, theta, rmsd

# %% [markdown]
# values = []
# i = 60
# A, y, w, theta, rmsd = getvars(1/i)
# print('co', 1/i, 'amp', A, 'gamma', y, 'omega', w, 'theta', theta, 'rmsd', rmsd)
# values.append([1/i, A, y, w, theta, rmsd])

# %% [markdown]
# t = data['time']
# phi = midp
# # y = .05
# pos = A*np.e**(-y*t)*np.cos(w*t+theta)+phi
# print(getrmsd(pos))
# ax = plt.subplot()
# fig = plt.subplot(111)
# ax.set_xlabel('time (s)')
# ax.set_ylabel('position (m)')
# ax.set_title('observed pendulum motion compared to calculation based in theory')
# ax.plot(data['time'], data['x'], label='collected position data')
# ax.plot(t, pos, color=(1,0,1), label='estimation based on collected data')
# ax.axhline(np.average(data['x']), color=(1,0,0), label='offset')
# ax.legend()
# # ax.set_xlim(0, 30)
# # ax.set_ylim(.4, .6)
# ax.figure.savefig('lab1_x-t_estimated')

# %% [markdown]
# theta

# %% [markdown]
# y

# %% [markdown]
# print(A, y, w, theta)

# %% [markdown]
# phi

# %% [markdown]
# angfreq = np.sqrt(9.807/height)

# %% [markdown]
# angfreq

# %% [markdown]
# np.sqrt(((w - angfreq)**2).mean())

# %% [markdown]
# periods = []
# for i in range(len(maxes)-1):
#     periods.append(data['time'][i+1]-data['time'][i])

# %% [markdown]
# np.average(periods)

# %% [markdown]
# np.sqrt(((periods-np.average(periods))**2).mean())

# %% [markdown]
# T = np.average(periods)

# %% [markdown]
# w = 2*np.pi/T
